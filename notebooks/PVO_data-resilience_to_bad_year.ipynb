# %%
from sys import path
path.append('..')
from clearsky.main import IterativeClearSky
from clearsky.utilities import CONFIG1
import s3fs
import pandas as pd
import numpy as np
from numpy.fft import fft2, ifft2, fftshift
import matplotlib.pyplot as plt
import seaborn as sns
from cvxpy import SolverError
sns.set(context='talk', style='darkgrid', palette='colorblind')
# %matplotlib inline
TZ_LOOKUP = {
    'America/Anchorage': 9,
    'America/Chicago': 6,
    'America/Denver': 7,
    'America/Los_Angeles': 8,
    'America/New_York': 5,
    'America/Phoenix': 7,
    'Pacific/Honolulu': 10
}
from datetime import datetime

# %%
def load_sys(n=None, idnum=None, local=True):
    if local:
        base = '../data/PVO/'
    if not local:
        base = 's3://pvinsight.nrel/PVO/'
    meta = pd.read_csv('../data/PVO/sys_meta.csv')
    if n is not None:
        idnum = meta['ID'][n]
    elif idnum is not None:
        n = meta[meta['ID'] == idnum].index[0]
    else:
        print('must provide index or ID')
        return
    df = pd.read_csv(base+'PVOutput/{}.csv'.format(idnum), index_col=0,
                      parse_dates=[0], usecols=[1, 3])
    tz = meta['TimeZone'][n]
    df.index = df.index.tz_localize(tz).tz_convert('Etc/GMT+{}'.format(TZ_LOOKUP[tz]))   # fix daylight savings
    start = df.index[0]
    end = df.index[-1]
    time_index = pd.date_range(start=start, end=end, freq='5min')
    df = df.reindex(index=time_index, fill_value=0)
    print(n, idnum)
    return df

# %%
n = 572#np.random.randint(642)
idnum = 6577
df = load_sys(idnum=idnum, local=False)
# Out:
# 63 6577

# %%
days = df.resample('D').max().index[1:-1]
start = days[0]
end = days[-1]
print(start.date(), end.date())
# Out:
# 2012-04-20 2017-07-30

# %%
end - start
# Out:
# Timedelta('1927 days 00:00:00')

# %%
D = df.loc[start:end].iloc[:-1].values.reshape(288, -1, order='F')
ics = IterativeClearSky(D)
ics.fixedTimeStamps
# Out:
# False

# %%
_ = ics.plot_D(show_days=True)

# %%
_ = ics.plot_singular_vectors(show_days=True)

# %%
_ = ics.plot_energy()

# %%
ics.minimize_objective(**CONFIG1)
# Out:
# starting at 2045896381.546 [6809161.791275848, 421.3121467422722, 1622612165.0657308, 416474633.37661326]
# iteration 1: 6331966.208 [6.00245027e+06 4.60406000e+02 3.29055479e+05 5.60000000e-02]
# iteration 2: 5634992.392 [5.34040738e+06 8.34520000e+02 2.93750439e+05 5.40000000e-02]
# iteration 3: 5589412.035 [5.29884294e+06 9.17563000e+02 2.89651424e+05 1.08000000e-01]
# iteration 4: 5581400.876 [5.29125871e+06 1.01036200e+03 2.89131709e+05 1.00000000e-01]
# Minimization complete in 4.06 minutes

# %%
print(np.round((
    ics.residuals_median,
    ics.residuals_variance,
    ics.residual_l0_norm
), 3), ics.isProblemStatusError, ics.isSolverError, ics.f1Increase, ics.objIncrease)
# Out:
# [0.186 0.272 0.076] False False False False

# %%
ics.D.shape[1]
# Out:
# 1927

# %%
np.sum(ics.weights > 1e-1)
# Out:
# 447

# %% [markdown]
# Here is the estimated degradation rate (year on year energy-yield) for the system:

# %%
ics.beta.value
# Out:
# array(-0.00184835)

# %%
_ = ics.plot_LR()

# %%
_ = ics.plot_measured_clear(figsize=(12, 10), show_days=True)

# %%
_ = ics.ts_plot(309)

# %%
_ = ics.ts_plot_with_weights(750)

# %%
_ = ics.plot_energy(show_clear=True)

# %%
sns.set_context('notebook')

# %%
plt.figure(figsize=(7, 5*7/10))
plt.plot(range(ics.D.shape[1]), np.sum(ics.D, axis=0) / 1000, linewidth=1, label='measured')
plt.plot(range(ics.D.shape[1]), np.sum(ics.L_cs.value.dot(ics.R_cs.value), axis=0) / 1000, linewidth=1, label='SCSF estimate')
plt.legend(loc=8)
plt.title('Daily Energy')
plt.ylabel('kWh')
plt.xlabel('Day Number')
plt.ylim(200, 750)
# Out:
# (200, 750)

# %%
_ = ics.plot_measured_clear(figsize=(7, 4*7/5), show_days=True)

# %% [markdown]
# ## Extra notes and scratch work

# %%
FS = fft2(D)
with sns.axes_style("white"):
    m, n = D.shape
    i = int(m / 2 - 75)
    j = int(n / 2 - 75)
    plt.figure(figsize=(12,12))
    plt.imshow(np.log(np.abs(np.fft.fftshift(FS)[i:-i, j:-j])**2))

# %%
fltr = np.zeros_like(D, dtype=np.float)
m, n = D.shape
c = (m // 2, n // 2)
r = 25
if m % 2 == 0:
    di = 0
else:
    di = 1
if n % 2 == 0:
    dj = 0
else:
    dj = 1
y, x = np.ogrid[-c[0]:c[0]+di, -c[1]:c[1]+dj]
mask = x ** 2 + y ** 2 <= r ** 2
fltr[mask] = 1
FS_filtered = fftshift(np.multiply(fftshift(FS), fltr))
D_filtered = np.abs(ifft2(FS_filtered))

# %%
with sns.axes_style("white"):
    fig, ax = plt.subplots(nrows=1, figsize=(12,6), sharex=True)
    foo = ax.imshow(D_filtered, cmap='hot', interpolation='none', aspect='auto')
    #plt.colorbar(label='kW')
    ax.set_title('Measured power')
    plt.colorbar(foo, ax=ax, label='kW')
    ax.set_xlabel('Day number')
    ax.set_yticks([])
    ax.set_ylabel('Time of day')
